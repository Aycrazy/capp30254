# %% [markdown]
# # Machine Learning Diagnostic

# %%
import pandas as pd
import urllib
import re
from functools import reduce
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')
from pandas.io.json import json_normalize
import json
import requests
from datetime import datetime

# %%
def soda_loop(url):
    '''
    This function takes an api key of a version of the identified 311 service call dataset saved in socrata
    and loops through the dataset until all the data is retrieved
    
    Input:
        url - chicago data portal api endpoint
    Output:
        pandas database
    '''
    offset_num = 0
    df = pd.DataFrame()
    count = 0
    use_url = url
    while len(pd.read_json(use_url)):

        df = pd.concat([df,pd.read_json(use_url)])
        
        use_url = url
  
        offset_num+=50000
   
        use_url=url+'&$offset={}'.format(offset_num)
                
        count+=1
        
        print(use_url)
        
    return df

# %%
cd Documents/capp30254/
# Out:
# /Users/andrewyaspan/Documents/capp30254

# %%
#query 311 graffiti data
raw_graffiti = soda_loop('https://data.cityofchicago.org/resource/qr2f-jf4g.json?$limit=50000')

#query 311 vacant lot and abandon buildings reported
raw_vac = soda_loop('https://data.cityofchicago.org/resource/4mhb-6abn.json?$limit=50000')


#query 311 potholes reported
raw_ph = soda_loop('https://data.cityofchicago.org/resource/ej8m-yavt.json?$limit=50000')

#query 311 sanitation code complaints
raw_san = soda_loop('https://data.cityofchicago.org/resource/tybt-vtit.json?$limit=50000')
# Out:
# https://data.cityofchicago.org/resource/qr2f-jf4g.json?$limit=50000&$offset=50000
# https://data.cityofchicago.org/resource/qr2f-jf4g.json?$limit=50000&$offset=100000
# https://data.cityofchicago.org/resource/qr2f-jf4g.json?$limit=50000&$offset=150000
# https://data.cityofchicago.org/resource/4mhb-6abn.json?$limit=50000&$offset=50000
# https://data.cityofchicago.org/resource/ej8m-yavt.json?$limit=50000&$offset=50000
# https://data.cityofchicago.org/resource/ej8m-yavt.json?$limit=50000&$offset=100000
# https://data.cityofchicago.org/resource/tybt-vtit.json?$limit=50000&$offset=50000

# %%
raw_ph = pd.read_csv('potholes_last_year.csv')

raw_vac = pd.read_csv('vacant_last_year.csv')

raw_san = pd.read_csv('sanitation_last_year.csv')

raw_graffiti = pd.read_csv('graffiti_last_year.csv')

# %%
pd.set_option("display.max_columns",80)
pd.set_option("display.max_rows",305)

# %%
raw_vac['street_address'] = raw_vac[raw_vac.columns[[0,1,2,3]]].apply(lambda x: ' '.join(x.astype(str).astype(str)),axis=1)

# %%
raw_vac = raw_vac.drop(raw_vac.columns[[0,1,2,3]],1)

# %%
#pd.merge(raw_graffiti, raw_vac, raw_ph, raw_san, how='inner', on=['latitude','longitude'],
#         left_index=False, right_index=False, sort=True, copy=True, indicator=False)

raw_vac_e = raw_vac.rename(index=str, columns={'date_service_request_was_received':'creation_date','service_request_type':'type_of_service_request'})
#raw_vac_e = raw_vac.rename(index=str, columns={'service_request_type':'type_of_service_request'})
dfs = [raw_graffiti, raw_vac_e, raw_ph, raw_san]
raw_311 = pd.concat(dfs)
raw_311_sub = raw_311[['creation_date','completion_date','community_area','street_address','type_of_service_request', 'latitude', 'longitude','police_district','ward','is_building_open_or_boarded_','number_of_potholes_filled_on_block','what_type_of_surface_is_the_graffiti_on_','what_is_the_nature_of_this_code_violation_','x_coordinate','y_coordinate','zip']].copy()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-464-52e52bba538f> in <module>()
#       6 dfs = [raw_graffiti, raw_vac_e, raw_ph, raw_san]
#       7 raw_311 = pd.concat(dfs)
# ----> 8 raw_311_sub = raw_311[['creation_date','completion_date','community_area','street_address','type_of_service_request', 'latitude', 'longitude','police_district','ward','is_building_open_or_boarded_','number_of_potholes_filled_on_block','what_type_of_surface_is_the_graffiti_on_','what_is_the_nature_of_this_code_violation_','x_coordinate','y_coordinate','zip']].copy()
#
# /Users/andrewyaspan/anaconda3/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1989         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1990             # either boolean or fancy integer index
# -> 1991             return self._getitem_array(key)
#    1992         elif isinstance(key, DataFrame):
#    1993             return self._getitem_frame(key)
#
# /Users/andrewyaspan/anaconda3/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2033             return self.take(indexer, axis=0, convert=False)
#    2034         else:
# -> 2035             indexer = self.ix._convert_to_indexer(key, axis=1)
#    2036             return self.take(indexer, axis=1, convert=True)
#    2037
#
# /Users/andrewyaspan/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1212                 mask = check == -1
#    1213                 if mask.any():
# -> 1214                     raise KeyError('%s not in index' % objarr[mask])
#    1215
#    1216                 return _values_from_object(indexer)
#
# KeyError: "['creation_date' 'completion_date' 'community_area'\n 'type_of_service_request' 'latitude' 'longitude' 'police_district' 'ward'\n 'is_building_open_or_boarded_' 'number_of_potholes_filled_on_block'\n 'what_type_of_surface_is_the_graffiti_on_'\n 'what_is_the_nature_of_this_code_violation_' 'x_coordinate' 'y_coordinate'\n 'zip'] not in index"

# %%
raw_311_sub.to_csv('chicago_combined.csv',sep=',')

# %%
raw_311_sub = pd.read_csv('chicago_combined.csv')
raw_311_sub = raw_311_sub.drop('Unnamed: 0', axis=1)
# Out:
# /Users/andrewyaspan/anaconda3/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (10,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
def sub_san(df):
    is_san = df['type_of_service_request'] == "Sanitation Code Violation"
    sanitation = df[is_san]
    return sanitation

def sub_vac(df):
    is_vac = df['type_of_service_request'] == "Vacant/Abandoned Building"
    vacant = df[is_vac]
    return vacant

def sub_ph(df):
    is_ph = df['type_of_service_request'] == "Pothole in Street"
    potholes = df[is_ph]
    return potholes

def sub_graf(df):
    is_graf = df['type_of_service_request'] == "Graffiti Removal"
    graffiti = df[is_graf]
    return graffiti

# %% [markdown]
# # Tables and Graphs by type of Service Request

# %%
pd.DataFrame(raw_311_sub['type_of_service_request'].value_counts())
# Out:
#                            type_of_service_request
# Graffiti Removal                            116894
# Pothole in Street                            55801
# Sanitation Code Violation                    21453
# Vacant/Abandoned Building                     4718

# %%
raw_311_sub['time_to_complete'] = pd.to_datetime(raw_311_sub['completion_date'])-pd.to_datetime(raw_311_sub['creation_date'])
raw_311_sub.groupby('time_to_complete').size().to_frame().rename(columns={0:'Response Time'}).plot(rot=70)
plt.show()

# %%
graffiti = sub_graf(raw_311_sub)
graffiti.groupby('time_to_complete').size().to_frame().rename(columns={0:'Response Time'}).plot(rot=70)
plt.show()

# %%
sanitation = sub_san(raw_311_sub)
sanitation.groupby('time_to_complete').size().to_frame().rename(columns={0:'Response Time'}).plot(rot=70)
plt.show()

# %%
raw_311_sub['type_of_service_request'].value_counts().plot("bar")
plt.figure()
plt.show()

# %% [markdown]
# <h3><b>Interesting discovery number 1</b>: The top request is <b>graffiti removal</b> by almost <i><b>50,000 requests</b></i><h3>

# %%
raw_311_sub.groupby('COMMUNITY').size().to_frame().rename(columns={0:'Service Requests'}).plot(kind='bar', fontsize=10,rot=90, figsize =(20,10))
plt.figure()
plt.show()

# %%
areas = pd.read_csv('CommAreas.csv')
areas.rename(columns = {'AREA_NUMBE': 'community area'})
raw_311_sub['community area'] = raw_311_sub.community_area.dropna().astype(int)
raw_311_sub = raw_311_sub.join(areas, on= 'community area')
raw_311_sub.groupby('COMMUNITY').size().to_frame().transpose()
# Out:
# COMMUNITY  ALBANY PARK  ARCHER HEIGHTS  ARMOUR SQUARE  ASHBURN  \
# 0                 1642             639           1019     1542
#
# COMMUNITY  AUBURN GRESHAM  AUSTIN  AVALON PARK  AVONDALE  BELMONT CRAGIN  \
# 0                    1626    3187          334      6293             614
#
# COMMUNITY  BEVERLY  BRIDGEPORT  BRIGHTON PARK  BURNSIDE  CALUMET HEIGHTS  \
# 0             3734        3733           2881       866              664
#
# COMMUNITY  CHATHAM  CHICAGO LAWN  CLEARING  DOUGLAS  DUNNING  \
# 0              308          4884      2973      221     5834
#
# COMMUNITY  EAST GARFIELD PARK  EAST SIDE  EDGEWATER  EDISON PARK  ENGLEWOOD  \
# 0                         898        381       1263          366       3364
#
# COMMUNITY  FOREST GLEN  FULLER PARK  GAGE PARK  GARFIELD RIDGE  \
# 0                 1280         4408       2350             216
#
# COMMUNITY  GRAND BOULEVARD  GREATER GRAND CROSSING  HEGEWISCH  HERMOSA  \
# 0                     2683                    3765       1525     1920
#
# COMMUNITY  HUMBOLDT PARK  HYDE PARK  IRVING PARK  JEFFERSON PARK  KENWOOD  \
# 0                   3446       4298         3972            1935     4548
#
# COMMUNITY  LAKE VIEW  LINCOLN PARK  LINCOLN SQUARE  LOGAN SQUARE  LOOP  \
# 0               1375          1982            4558          9622   209
#
# COMMUNITY  LOWER WEST SIDE  MCKINLEY PARK  MONTCLARE  MORGAN PARK  \
# 0                     2920           1882       1733         1449
#
# COMMUNITY  MOUNT GREENWOOD  NEAR NORTH SIDE  NEAR SOUTH SIDE  NEAR WEST SIDE  \
# 0                     1112              105              664            4346
#
# COMMUNITY  NEW CITY  NORTH CENTER  NORTH LAWNDALE  NORTH PARK  NORWOOD PARK  \
# 0              6616           227            1512        1325           323
#
# COMMUNITY  OAKLAND  OHARE  PORTAGE PARK  PULLMAN  RIVERDALE  ROGERS PARK  \
# 0             2467   1092          4822      817       1579          634
#
# COMMUNITY  ROSELAND  SOUTH CHICAGO  SOUTH DEERING  SOUTH LAWNDALE  \
# 0              1817            778           2257            5987
#
# COMMUNITY  SOUTH SHORE  UPTOWN  WASHINGTON HEIGHTS  WASHINGTON PARK  \
# 0                  692    6729                2322             6219
#
# COMMUNITY  WEST ELSDON  WEST ENGLEWOOD  WEST GARFIELD PARK  WEST LAWN  \
# 0                 3708            1074                 715       3436
#
# COMMUNITY  WEST PULLMAN  WEST RIDGE  WEST TOWN  WOODLAWN
# 0                   977        5092      12366      2872

# %% [markdown]
# <h3><b>Interesting discovery number 2</b>: <b>West Town</b> has the <b>most service requests</b> with <i><b>12366</b></i></h3>
#
# <h3><b>Interesting discovery number 3</b>: <b>Near North Side</b> has the <b>fewest</b> with only 105 <i><b>requests</b></i></h3>

# %%
by_area = raw_311_sub.groupby(['COMMUNITY', 'type_of_service_request']).size().to_frame()
by_area
# Out:
#                                                      0
# COMMUNITY              type_of_service_request
# ALBANY PARK            Graffiti Removal            954
#                        Pothole in Street           516
#                        Sanitation Code Violation   169
#                        Vacant/Abandoned Building     3
# ARCHER HEIGHTS         Graffiti Removal            167
#                        Pothole in Street           368
#                        Sanitation Code Violation    78
#                        Vacant/Abandoned Building    26
# ARMOUR SQUARE          Graffiti Removal            688
#                        Pothole in Street           250
#                        Sanitation Code Violation    79
#                        Vacant/Abandoned Building     2
# ASHBURN                Graffiti Removal            160
#                        Pothole in Street           541
#                        Sanitation Code Violation   504
#                        Vacant/Abandoned Building   337
# AUBURN GRESHAM         Graffiti Removal             67
#                        Pothole in Street           826
#                        Sanitation Code Violation   490
#                        Vacant/Abandoned Building   243
# AUSTIN                 Graffiti Removal            790
#                        Pothole in Street          1435
#                        Sanitation Code Violation   808
#                        Vacant/Abandoned Building   154
# AVALON PARK            Graffiti Removal             50
#                        Pothole in Street           161
#                        Sanitation Code Violation    84
#                        Vacant/Abandoned Building    39
# AVONDALE               Graffiti Removal           5357
#                        Pothole in Street           639
#                        Sanitation Code Violation   277
#                        Vacant/Abandoned Building    20
# BELMONT CRAGIN         Graffiti Removal            282
#                        Pothole in Street           296
#                        Sanitation Code Violation    34
#                        Vacant/Abandoned Building     2
# BEVERLY                Graffiti Removal           1942
#                        Pothole in Street          1375
#                        Sanitation Code Violation   351
#                        Vacant/Abandoned Building    66
# BRIDGEPORT             Graffiti Removal           2686
#                        Pothole in Street           470
#                        Sanitation Code Violation   568
#                        Vacant/Abandoned Building     9
# BRIGHTON PARK          Graffiti Removal           1217
#                        Pothole in Street          1280
#                        Sanitation Code Violation   350
#                        Vacant/Abandoned Building    34
# BURNSIDE               Graffiti Removal             87
#                        Pothole in Street           351
#                        Sanitation Code Violation   304
#                        Vacant/Abandoned Building   124
# CALUMET HEIGHTS        Graffiti Removal             37
#                        Pothole in Street           452
#                        Sanitation Code Violation   115
#                        Vacant/Abandoned Building    60
# CHATHAM                Graffiti Removal             41
#                        Pothole in Street           187
#                        Sanitation Code Violation    66
#                        Vacant/Abandoned Building    14
# CHICAGO LAWN           Graffiti Removal           4126
#                        Pothole in Street           461
#                        Sanitation Code Violation   250
#                        Vacant/Abandoned Building    47
# CLEARING               Graffiti Removal           1781
#                        Pothole in Street           579
#                        Sanitation Code Violation   381
#                        Vacant/Abandoned Building   232
# DOUGLAS                Graffiti Removal             79
#                        Pothole in Street           141
#                        Vacant/Abandoned Building     1
# DUNNING                Graffiti Removal           3937
#                        Pothole in Street          1324
#                        Sanitation Code Violation   555
#                        Vacant/Abandoned Building    18
# EAST GARFIELD PARK     Graffiti Removal            239
#                        Pothole in Street           269
#                        Sanitation Code Violation   312
#                        Vacant/Abandoned Building    78
# EAST SIDE              Graffiti Removal             36
#                        Pothole in Street           268
#                        Sanitation Code Violation    45
#                        Vacant/Abandoned Building    32
# EDGEWATER              Graffiti Removal             92
#                        Pothole in Street           906
#                        Sanitation Code Violation   197
#                        Vacant/Abandoned Building    68
# EDISON PARK            Graffiti Removal            163
#                        Pothole in Street           180
#                        Sanitation Code Violation    23
# ENGLEWOOD              Graffiti Removal           2296
#                        Pothole in Street           898
#                        Sanitation Code Violation   150
#                        Vacant/Abandoned Building    20
# FOREST GLEN            Graffiti Removal            340
#                        Pothole in Street           796
#                        Sanitation Code Violation   138
#                        Vacant/Abandoned Building     6
# FULLER PARK            Graffiti Removal           2245
#                        Pothole in Street          1676
#                        Sanitation Code Violation   477
#                        Vacant/Abandoned Building    10
# GAGE PARK              Graffiti Removal           1756
#                        Pothole in Street           313
#                        Sanitation Code Violation   259
#                        Vacant/Abandoned Building    22
# GARFIELD RIDGE         Graffiti Removal              8
#                        Pothole in Street           179
#                        Sanitation Code Violation     8
#                        Vacant/Abandoned Building    21
# GRAND BOULEVARD        Graffiti Removal           1778
#                        Pothole in Street           520
#                        Sanitation Code Violation   380
#                        Vacant/Abandoned Building     5
# GREATER GRAND CROSSING Graffiti Removal           2353
#                        Pothole in Street           777
#                        Sanitation Code Violation   451
#                        Vacant/Abandoned Building   184
# HEGEWISCH              Graffiti Removal            103
#                        Pothole in Street           778
#                        Sanitation Code Violation   425
#                        Vacant/Abandoned Building   219
# HERMOSA                Graffiti Removal           1376
#                        Pothole in Street           328
#                        Sanitation Code Violation   206
#                        Vacant/Abandoned Building    10
# HUMBOLDT PARK          Graffiti Removal           2012
#                        Pothole in Street           714
#                        Sanitation Code Violation   607
#                        Vacant/Abandoned Building   113
# HYDE PARK              Graffiti Removal           2390
#                        Pothole in Street          1043
#                        Sanitation Code Violation   857
#                        Vacant/Abandoned Building     8
# IRVING PARK            Graffiti Removal           1999
#                        Pothole in Street          1551
#                        Sanitation Code Violation   406
#                        Vacant/Abandoned Building    16
# JEFFERSON PARK         Graffiti Removal            174
#                        Pothole in Street          1608
#                        Sanitation Code Violation   144
#                        Vacant/Abandoned Building     9
# KENWOOD                Graffiti Removal           3615
#                        Pothole in Street           726
#                        Sanitation Code Violation   205
#                        Vacant/Abandoned Building     2
# LAKE VIEW              Graffiti Removal             92
#                        Pothole in Street           803
#                        Sanitation Code Violation   351
#                        Vacant/Abandoned Building   129
# LINCOLN PARK           Graffiti Removal            408
#                        Pothole in Street           682
#                        Sanitation Code Violation   423
#                        Vacant/Abandoned Building   469
# LINCOLN SQUARE         Graffiti Removal           3610
#                        Pothole in Street           641
#                        Sanitation Code Violation   297
#                        Vacant/Abandoned Building    10
# LOGAN SQUARE           Graffiti Removal           7707
#                        Pothole in Street          1112
#                        Sanitation Code Violation   775
#                        Vacant/Abandoned Building    28
# LOOP                   Graffiti Removal             49
#                        Pothole in Street            91
#                        Sanitation Code Violation    43
#                        Vacant/Abandoned Building    26
# LOWER WEST SIDE        Graffiti Removal           1947
#                        Pothole in Street           842
#                        Sanitation Code Violation   130
#                        Vacant/Abandoned Building     1
# MCKINLEY PARK          Graffiti Removal            179
#                        Pothole in Street          1087
#                        Sanitation Code Violation   481
#                        Vacant/Abandoned Building   135
# MONTCLARE              Graffiti Removal            589
#                        Pothole in Street           978
#                        Sanitation Code Violation   153
#                        Vacant/Abandoned Building    13
# MORGAN PARK            Graffiti Removal             61
#                        Pothole in Street           841
#                        Sanitation Code Violation   433
#                        Vacant/Abandoned Building   114
# MOUNT GREENWOOD        Graffiti Removal             72
#                        Pothole in Street           900
#                        Sanitation Code Violation   116
#                        Vacant/Abandoned Building    24
# NEAR NORTH SIDE        Graffiti Removal             15
#                        Pothole in Street            64
#                        Sanitation Code Violation    22
#                        Vacant/Abandoned Building     4
# NEAR SOUTH SIDE        Graffiti Removal            372
#                        Pothole in Street           231
#                        Sanitation Code Violation    61
# NEAR WEST SIDE         Graffiti Removal           2602
#                        Pothole in Street          1305
#                        Sanitation Code Violation   416
#                        Vacant/Abandoned Building    23
# NEW CITY               Graffiti Removal           5717
#                        Pothole in Street           584
#                        Sanitation Code Violation   275
#                        Vacant/Abandoned Building    40
# NORTH CENTER           Graffiti Removal             37
#                        Pothole in Street            96
#                        Sanitation Code Violation    50
#                        Vacant/Abandoned Building    44
# NORTH LAWNDALE         Graffiti Removal            487
#                        Pothole in Street           523
#                        Sanitation Code Violation   422
#                        Vacant/Abandoned Building    80
# NORTH PARK             Graffiti Removal            165
#                        Pothole in Street          1093
#                        Sanitation Code Violation    65
#                        Vacant/Abandoned Building     2
# NORWOOD PARK           Graffiti Removal             65
#                        Pothole in Street           170
#                        Sanitation Code Violation    77
#                        Vacant/Abandoned Building    11
# OAKLAND                Graffiti Removal           1549
#                        Pothole in Street           726
#                        Sanitation Code Violation   189
#                        Vacant/Abandoned Building     3
# OHARE                  Graffiti Removal            166
#                        Pothole in Street           832
#                        Sanitation Code Violation    73
#                        Vacant/Abandoned Building    21
# PORTAGE PARK           Graffiti Removal           3652
#                        Pothole in Street           846
#                        Sanitation Code Violation   312
#                        Vacant/Abandoned Building    12
# PULLMAN                Graffiti Removal             80
#                        Pothole in Street           548
#                        Sanitation Code Violation   143
#                        Vacant/Abandoned Building    46
# RIVERDALE              Graffiti Removal            786
#                        Pothole in Street           668
#                        Sanitation Code Violation   101
#                        Vacant/Abandoned Building    24
# ROGERS PARK            Graffiti Removal             62
#                        Pothole in Street           554
#                        Sanitation Code Violation    17
#                        Vacant/Abandoned Building     1
# ROSELAND               Graffiti Removal            620
#                        Pothole in Street           638
#                        Sanitation Code Violation   362
#                        Vacant/Abandoned Building   197
# SOUTH CHICAGO          Graffiti Removal            206
#                        Pothole in Street           494
#                        Sanitation Code Violation    74
#                        Vacant/Abandoned Building     4
# SOUTH DEERING          Graffiti Removal            216
#                        Pothole in Street          1075
#                        Sanitation Code Violation   652
#                        Vacant/Abandoned Building   314
# SOUTH LAWNDALE         Graffiti Removal           4980
#                        Pothole in Street           741
#                        Sanitation Code Violation   231
#                        Vacant/Abandoned Building    35
# SOUTH SHORE            Graffiti Removal             86
#                        Pothole in Street           391
#                        Sanitation Code Violation   176
#                        Vacant/Abandoned Building    39
# UPTOWN                 Graffiti Removal           5297
#                        Pothole in Street          1100
#                        Sanitation Code Violation   288
#                        Vacant/Abandoned Building    44
# WASHINGTON HEIGHTS     Graffiti Removal            238
#                        Pothole in Street          1133
#                        Sanitation Code Violation   640
#                        Vacant/Abandoned Building   311
# WASHINGTON PARK        Graffiti Removal           4547
#                        Pothole in Street          1154
#                        Sanitation Code Violation   506
#                        Vacant/Abandoned Building    12
# WEST ELSDON            Graffiti Removal           3319
#                        Pothole in Street           298
#                        Sanitation Code Violation    82
#                        Vacant/Abandoned Building     9
# WEST ENGLEWOOD         Graffiti Removal            246
#                        Pothole in Street           658
#                        Sanitation Code Violation   160
#                        Vacant/Abandoned Building    10
# WEST GARFIELD PARK     Graffiti Removal            178
#                        Pothole in Street           192
#                        Sanitation Code Violation   256
#                        Vacant/Abandoned Building    89
# WEST LAWN              Graffiti Removal           2865
#                        Pothole in Street           430
#                        Sanitation Code Violation   129
#                        Vacant/Abandoned Building    12
# WEST PULLMAN           Graffiti Removal            273
#                        Pothole in Street           482
#                        Sanitation Code Violation   165
#                        Vacant/Abandoned Building    57
# WEST RIDGE             Graffiti Removal           3605
#                        Pothole in Street          1057
#                        Sanitation Code Violation   410
#                        Vacant/Abandoned Building    20
# WEST TOWN              Graffiti Removal           9468
#                        Pothole in Street          2106
#                        Sanitation Code Violation   756
#                        Vacant/Abandoned Building    36
# WOODLAWN               Graffiti Removal           1508
#                        Pothole in Street          1143
#                        Sanitation Code Violation   218
#                        Vacant/Abandoned Building     3

# %%
raw_311_sub.rename(columns={0:'Graffiti Removal'}).plot(kind='bar', fontsize=10,rot=90, figsize =(20,10))

# %% [markdown]
# # Tables and Graphs by Subtype

# %%
raw_graffiti['What Type of Surface is the Graffiti on?'].value_counts().plot('bar', color = 'g')
plt.figure()
plt.show()

# %% [markdown]
# <h2>Interesting Discovery 5: The most "graffitied" surface is painted metal. <h2>

# %%
raw_ph.groupby('NUMBER OF POTHOLES FILLED ON BLOCK').size().to_frame().rename(columns={0:'Potholes Filled'}).plot.density(rot=70, color = 'purple')
plt.show()

# %%
raw_ph['NUMBER OF POTHOLES FILLED ON BLOCK'].value_counts().plot.hist(orientation='horizontal', color = 'b')
plt.figure()
plt.show()

# %% [markdown]
#  <h3>Interesting discovery 4: Pot hole fillings are concentrated around particluar areas</h3>

# %%
potholes = sub_ph(raw_311_sub)
potholes.groupby('COMMUNITY').size().to_frame().rename(columns={0:'Service Requests'}).plot(kind='bar', fontsize=10,rot=90, figsize =(20,10))
plt.figure()
plt.show()

# %% [markdown]
# <h3> They tend to be located in areas of Downtown, and West of West Town north of Downtown, which according to Crain's (see http://www.chicagobusiness.com/article/20130108/BLOGS08/130109821/how-rich-is-your-neighborhood) are among the wealthiest areas of the city.<h3>

# %%
raw_vac['IS BUILDING OPEN OR BOARDED?'].value_counts().plot('bar')
plt.figure()
plt.show()

# %%
def find_fips(df):
    
        
    acs_df = pd.DataFrame()

    for row in df.itertuples():
        
        
        print(row[5])
        #if row[5] == 'Graffiti Removal':
            #continue
        
        
        print (row[1][6])
        
        #if int(row[1][6]) <= 6:
        lat = row[6]
        long = row[7]

        if str(lat) == 'nan':
            continue

        fcc_api_call = 'http://data.fcc.gov/api/block/find?format=json&latitude={}&longitude={}&showall=true'.format(lat,long)


        print(row[0])



        #B02008_001E: White Alone or in Combination with other races 
        #B02009_001E: Black Or African American Alone Or In Combination With One Or More Other Races 
        #B02011_001E:  Asian Alone Or In Combination With One Or More Other Races

        #acs_call = 'http://api.census.gov/data/2015/acs5?get=NAME,B02008_001E,B02009_001E,B02011_001E&for=block+group:{}&in=state:17&in=county:031&in=tract:{}&key=d53148b74dc29b6d066fe5ecbf2f030e63183f04'.format(block_group,tract)

        #acs_return = pd.DataFrame(pd.read_json(acs_call).ix[1]).transpose().reset_index()

        #street_type_acs = acs_return.join(pd.DataFrame(df.ix[r_index]).transpose().reset_index(), lsuffix='test')
        try:
            fcac = pd.read_json(fcc_api_call)
            fips = str(int(fcac['Block']['FIPS']))
        except ValueError:
            d = json.loads(requests.get(fcc_api_call).text)
            fips = pd.DataFrame(d['Block']['intersection'])['FIPS'][0]

        #block group digits
        block_group = fips[-4]

        #tract digits
        tract = fips[-10:-4]

        if fips == 'nan':
            continue
        #fcac = pd.read_json(fcc_api_call)

        df_addtract = pd.DataFrame(df.ix[row[0]]).transpose().reset_index().join(pd.DataFrame({'tract':tract, 'block group':block_group}, index=[0]))

        acs_df = pd.concat([acs_df, df_addtract])

        #if r_index == 97:
        #    return acs_df

    return acs_df

# %%
sort_sub_311 = raw_311_sub.sort('creation_date')
# Out:
# /Users/andrewyaspan/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':

# %%
sort_sub_311 = sort_sub_311.drop('Unnamed: 0', axis=1)

# %%
better_result = pd.read_json('chicago_combined_acs_correct.json')

# %%
better_result.transpose().head()
# Out:
#      block group community_area      completion_date        creation_date  \
# 0              1             65  2017-03-31T00:00:00  2017-03-31T00:00:00
# 1              4             30  2017-03-31T00:00:00  2017-03-31T00:00:00
# 10             1             28  2017-03-31T00:00:00  2017-03-31T00:00:00
# 100            3             59                 None  2017-03-31T00:00:00
# 1000           1             30  2017-03-28T00:00:00  2017-03-27T00:00:00
#
#      index is_building_open_or_boarded_ latitude longitude  \
# 0        0                         None  41.7844  -87.7136
# 1       24                         None  41.8529  -87.7005
# 10      44                         None  41.8608  -87.6857
# 100    182                         None  41.8341  -87.6754
# 1000  1638                         None  41.8517  -87.7013
#
#      number_of_potholes_filled_on_block police_district      street_address  \
# 0                                  None               8      3606 W 60TH ST
# 1                                  None              10      2922 W 21ST PL
# 10                                 None              12  1511 S WESTERN AVE
# 100                                None               9      2000 W 33RD ST
# 1000                               None              10    3021 W CERMAK RD
#
#        tract type_of_service_request ward  \
# 0     837300        Graffiti Removal   23
# 1     031400        Graffiti Removal   24
# 10    740200        Graffiti Removal   28
# 100   730600        Graffiti Removal   12
# 1000  561000        Graffiti Removal   12
#
#      what_is_the_nature_of_this_code_violation_  \
# 0                                          None
# 1                                          None
# 10                                         None
# 100                                        None
# 1000                                       None
#
#      what_type_of_surface_is_the_graffiti_on_ x_coordinate y_coordinate   zip
# 0                            Wood - Unpainted  1.15331e+06  1.86459e+06  None
# 1                           Brick - Unpainted  1.15673e+06  1.88959e+06  None
# 10                            Metal - Painted  1.16062e+06  1.89255e+06  None
# 100                         Brick - Unpainted  1.16356e+06  1.88279e+06  None
# 1000                  Other / Unknown Surface  1.15649e+06  1.88923e+06  None

# %%
better_result_tp = better_result.transpose()

# %%
better_result = better_result.drop('Unnamed: 0', axis=1)

# %%
best_result = find_fips(sort_sub_311.sample(n=1000))
# Out:
# Graffiti Removal
# 6
# 89977
# Pothole in Street
# 7
# 155104
# Sanitation Code Violation
# 6
# 193437
# Pothole in Street
# 4
# 173291
# Pothole in Street
# 0
# 148219
# Graffiti Removal
# 5
# 100043
# Graffiti Removal
# 7
# 81029
# Graffiti Removal
# 1
# 37386
# Pothole in Street
# 9
# 149341
# Graffiti Removal
# 2
# 27238
# Pothole in Street
# 1
# 139298
# Pothole in Street
# 2
# 142969
# Graffiti Removal
# 6
# 88959
# Pothole in Street
# 6
# 160065
# Graffiti Removal
# 6
# 90215
# Sanitation Code Violation
# 1
# 182619
# Graffiti Removal
# 0
# 46957
# Graffiti Removal
# 0
# 47715
# Graffiti Removal
# 7
# 82054
# Graffiti Removal
# 1
# 26953
# Graffiti Removal
# 7
# 79063
# Graffiti Removal
# 2
# 17479
# Graffiti Removal
# 6
# 87442
# Graffiti Removal
# 8
# 74263
# Pothole in Street
# 4
# 171909
# Graffiti Removal
# 9
# 58032
# Graffiti Removal
# 1
# 39076
# Pothole in Street
# 2
# 131874
# Sanitation Code Violation
# 7
# 190150
# Sanitation Code Violation
# 1
# 180741
# Graffiti Removal
# 2
# 30873
# Sanitation Code Violation
# 2
# 179709
# Graffiti Removal
# 9
# 63064
# Sanitation Code Violation
# 7
# 190527
# Pothole in Street
# 2
# 128725
# Graffiti Removal
# 3
# 3628
# Graffiti Removal
# 5
# 105960
# Graffiti Removal
# 6
# 87898
# Graffiti Removal
# 9
# 62120
# Pothole in Street
# 6
# 162644
# Graffiti Removal
# 1
# 41468
# Graffiti Removal
# 5
# 97196
# Graffiti Removal
fcac = pd.read_json('http://data.fcc.gov/api/block/find?format=json&latitude=41.78437373&longitude=-87.71364839&showall=true')

# %%
response = urllib.request.urlopen('http://api.census.gov/data/2015/acs5?get=NAME,B02008_001E,B02009_001E,B02011_001E&for=block+group:*&in=state:17&in=county:031&in=tract:*&key=d53148b74dc29b6d066fe5ecbf2f030e63183f04')
html=response.read()
df = pd.read_json(html, typ='frame')
new_header = df.iloc[0] #grab the first row for the header
df = df[1:] #take the data less the header row
df = df.rename(columns = new_header) #set the header row as the df header

# %%
merged_chicago_rand_acs = pd.merge(df, best_result, on=['block group','tract'], how = "inner")  ##THIS ONE IS KEY

# %%
merged_chicago_acs = pd.merge(df, better_result_tp, on=['tract'], how = "inner")  ##THIS ONE IS KEY

# %%
merge_chicago_acs_name = merged_chicago_acs.rename(columns = {'B02008_001E':'white', 'B02009_001E':'black','B02011_001E':'asian'})

# %%
merge_chicago_rand = merged_chicago_rand_acs.rename(columns = {'B02008_001E':'white', 'B02009_001E':'black','B02011_001E':'asian'})

# %% [markdown]
# # Plots of Chicago with Select ACS Data

# %% [markdown]
# I took a random sample of 1000 requests and matched with the population of residents of white, black and asian demographics based on the acs 5 year survey data based on tract and block.

# %%
#is_vacant = merge_chicago_rand['type_of_service_request'] == "Vacant/Abandoned Building"
vacant = sub_vac(merge_chicago_rand)
plt.figure()
vacant[['white','black','asian']].astype(float).reset_index(drop=True).plot(kind='line',stacked=True)
plt.show()

# %% [markdown]
# <h3>It seems that areas with high diversity call 311 about Vacant and Abandoned buildings.</h3>

# %%
is_pot = merge_chicago_rand['type_of_service_request'] == "Pothole in Street"
pothole = merge_chicago_rand[is_pot]
plt.figure()
pothole[['white','black','asian']].astype(float).reset_index(drop=True).plot(kind='line',stacked=True,fontsize=10,rot=90, figsize =(20,10) )
plt.show()

# %% [markdown]
# <h3> It is hard to draw a trends about what type of neighborhood makes more calls about potholes, there is a wide variation amongst people of each ethnicity.<h3>

# %%
#is_san = merge_chicago_rand['type_of_service_request'] == "Sanitation Code Violation"
sanitation = sub_san(merge_chicago_rand)
plt.figure()
sanitation[['white','black','asian']].astype(float).reset_index(drop=True).plot(kind='line',stacked=True, fontsize=10,rot=90, figsize =(20,10))
plt.show()

# %% [markdown]
# <h3>Similar to vacant and abandoned buildings seems that areas with high diversity call 311 about sanitation code violations.</h3>

# %%
#is_graf = merge_chicago_rand['type_of_service_request'] == "Grafitti Removal"
graffiti = sub_graf(merge_chicago_rand)
plt.figure()
graffiti[['white','black','asian']].astype(float).reset_index(drop=True).plot(kind='line',stacked=True, fontsize=10,rot=90, figsize =(20,10))
plt.show()
plt.show()

# %%
merge_chicago_rand.groupby('creation_date').size().to_frame().rename(columns={0:'Requests'}).plot(rot=70, color='b')
plt.show()

# %%
is_wolcott = raw_311_sub['street_address'] =='7500 S WOLCOTT AVE'
wolcott = raw_311_sub[is_wolcott]
wolcott
# Out:
#               creation_date      completion_date  community_area  \
# 170336  2016-05-02T00:00:00  2016-07-12T00:00:00            71.0
# 198288  2016-04-14T00:00:00  2016-04-22T00:00:00            71.0
#
#             street_address    type_of_service_request   latitude  longitude  \
# 170336  7500 S WOLCOTT AVE          Pothole in Street  41.757345 -87.671052
# 198288  7500 S WOLCOTT AVE  Sanitation Code Violation  41.757433 -87.670907
#
#         police_district  ward is_building_open_or_boarded_  \
# 170336              6.0  17.0                          NaN
# 198288              6.0  17.0                          NaN
#
#         number_of_potholes_filled_on_block  \
# 170336                                 3.0
# 198288                                 NaN
#
#        what_type_of_surface_is_the_graffiti_on_  \
# 170336                                      NaN
# 198288                                      NaN
#
#        what_is_the_nature_of_this_code_violation_  x_coordinate  y_coordinate  \
# 170336                                        NaN  1.164988e+06  1.854895e+06
# 198288                           Garbage in alley  1.164988e+06  1.854895e+06
#
#             zip  community area  \
# 170336  60620.0            71.0
# 198288      NaN            71.0
#
#                                                  the_geom  PERIMETER  AREA  \
# 170336  MULTIPOLYGON (((-87.63373383514987 41.72885272...        0.0   0.0
# 198288  MULTIPOLYGON (((-87.63373383514987 41.72885272...        0.0   0.0
#
#         COMAREA_  COMAREA_ID  AREA_NUMBE           COMMUNITY  AREA_NUM_1  \
# 170336       0.0         0.0        73.0  WASHINGTON HEIGHTS        73.0
# 198288       0.0         0.0        73.0  WASHINGTON HEIGHTS        73.0
#
#           SHAPE_AREA     SHAPE_LEN
# 170336  7.963575e+07  42222.598163
# 198288  7.963575e+07  42222.598163

# %% [markdown]
# <h3>The most likely service reqeust type from 7500 S Wolcott Ave is a pothole or sanitation code violation call.  I may be missing data, but it seems like the probability that the request is one for a pothole is 1/2 as is the probablity that it is a sanitation code violation.<h3>

# %%
is_nlawndale = raw_311_sub['COMMUNITY'] == 'NORTH LAWNDALE'
is_slawndale = raw_311_sub['COMMUNITY'] == 'SOUTH LAWNDALE'
is_uptown = raw_311_sub['COMMUNITY'] == 'UPTOWN'

# %%
nlawndale = raw_311_sub[is_nlawndale]
nlawndale.groupby('type_of_service_request').size().to_frame().plot(kind='bar', color = 'orange')
plt.show()

# %%
slawndale = raw_311_sub[is_slawndale]
slawndale.groupby('type_of_service_request').size().to_frame().plot(kind='bar', color = 'b')
plt.show()

# %% [markdown]
# <h3> Roughly 5500 requests for graffiti removal from North and South Lawndale. <h3>

# %%
uptown = raw_311_sub[is_uptown]
uptown['type_of_service_request'].value_counts().plot(kind='bar', color = 'g')
plt.show()

# %% [markdown]
# <h3> Slightly fewer requests come from Uptown.  So it seems like there is a fairly equal probablity that the request comes from the North/South Lawndale area than Uptown, but it seems only by around 5500 -5300/10800 --> 200/18000 = .019 (or 1.9%) </h3>

# %% [markdown]
# <h3> Calls about graffiti from Englewood were 100 calls out of 600 total requests: ((100/600)*(600/1000))/(600/1000) = 16% likelihood the call is about graffiti and came from Englewood. </h3>
#
# <h3>Calls about graffiti were 160 out of 400 total request: from Uptown (160/400)*(400/1000)/(400/1000) = 40% likelihood that the call is about graffiti and came from Uptown.
#
# It's about three times as likely that the call be from Uptown if it is about graffiti.</h3>
